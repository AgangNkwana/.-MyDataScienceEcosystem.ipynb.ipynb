# %% [markdown]
# # Data science tools and ecosystem

# %% [markdown]
# In this markdown, Data science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**
#
# * List of popular languages for Data Science
# * Common used libraries used by Data Scientists
# * Examples of analyzing arithmetic expressions using Python

# %% [markdown]
# ##### Some of the popular languages that data scientists use are:
# 1.Python <br>
# 2.R <br>
# 3.Java <br>
# 4.SQL <br>
# 5.SCALA <br>

# %% [markdown]
# #### Some of the commonly used libraries used by Data sientists are:
#
# 1.Theano <br>
# 2.Pytorch <br>
# 3.Scikit-Learn

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# |SAS                 |
# |Apache Spark        |
# |Tableau             |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:

# %% [markdown]
# This is a aimple arithmetic expression to multiply and add integers:

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# This will create 200 minutes to hours by dividing by 60

# %%
Minutes_to_convert = 200
Hours = (Minutes_to_convert)/60
print(Hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Agang Lethabo Nkwana
